# %% [markdown]
# <center><h1 style="background-color:#FFF176;"><i><font color=" #222222">Project Title: World Population Analysis <hr></font><i></h1></center>

# %% [markdown]
# <center><h3 style="background-color: #FFD54F;color:#222222"><i>PART 1: Load and Explore the Datase</i><h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')   # ignore unnecessary warnings

# %%
#Load The Dataset
df=pd.read_csv(r'C:\Users\PC\Desktop\world_population.csv')

# %%
# Show first 5 rows to understand the structure
print("🔹 First 5 rows of the dataset:")
df.head()
# Out:
# 🔹 First 5 rows of the dataset:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
# ...

# %%
# Check column names
print("\n🔹 Column names:")
df.columns.tolist()
# Out:
# 🔹 Column names:
# ['Rank',
#  'CCA3',
#  'Country/Territory',
#  'Capital',
#  'Continent',
#  '2022 Population',
#  '2020 Population',
#  '2015 Population',
#  '2010 Population',
#  '2000 Population',
#  '1990 Population',
#  '1980 Population',
#  '1970 Population',
#  'Area (km²)',
#  'Density (per km²)',
#  'Growth Rate',
#  'World Population Percentage']

# %%
# Check Shape of Dataset
print("\n🔹 Shape of Dataset:")
df.shape
# Out:
# 🔹 Shape of Dataset:
# (234, 17)

# %%
# Summary of dataset (rows, columns, nulls, datatypes)
print("\n🔹 Dataset info:")
df.info()
# Out:
# 🔹 Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
# ...

# %%
# Check for missing values
print("\n🔹 Missing values in each column:")
df.isnull().sum()
# Out:
# 🔹 Missing values in each column:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
# View basic statistics
print("\n🔹 Basic statistics of numerical columns:")
df.describe()
# Out:
# 🔹 Basic statistics of numerical columns:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %% [markdown]
# <center><h3 style="background-color: #FFD54F;color:#222222"><i>PART 2: Clean and Prepare the Data</i></h3>

# %%
# Preview column names for better decision-making
print("🔹 Current Columns:")
df.columns.to_list()
# Out:
# 🔹 Current Columns:
# ['Rank',
#  'CCA3',
#  'Country/Territory',
#  'Capital',
#  'Continent',
#  '2022 Population',
#  '2020 Population',
#  '2015 Population',
#  '2010 Population',
#  '2000 Population',
#  '1990 Population',
#  '1980 Population',
#  '1970 Population',
#  'Area (km²)',
#  'Density (per km²)',
#  'Growth Rate',
#  'World Population Percentage']

# %%
# Drop columns we won't use in analysis or modeling (like 'CCA3', 'Capital')
df.drop(['CCA3' , 'Capital' ], axis=1, inplace=True)

# %%
# Confirm changes
print("\n Columns after dropping unused ones:")
df.columns.to_list()
# Out:
#  Columns after dropping unused ones:
# ['Rank',
#  'Country/Territory',
#  'Continent',
#  '2022 Population',
#  '2020 Population',
#  '2015 Population',
#  '2010 Population',
#  '2000 Population',
#  '1990 Population',
#  '1980 Population',
#  '1970 Population',
#  'Area (km²)',
#  'Density (per km²)',
#  'Growth Rate',
#  'World Population Percentage']

# %%
# Check for duplicate rows
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Length: 234, dtype: bool

# %%
# Rename columns for easy access (optional)
df.rename(columns=lambda x: x.strip().replace(' ','_').replace('(','').replace(')', ''), inplace=True)

# %%
print("\n📌 Cleaned column names:")
df.columns.to_list()
# Out:
# 📌 Cleaned column names:
# ['Rank',
#  'Country/Territory',
#  'Continent',
#  '2022_Population',
#  '2020_Population',
#  '2015_Population',
#  '2010_Population',
#  '2000_Population',
#  '1990_Population',
#  '1980_Population',
#  '1970_Population',
#  'Area_km²',
#  'Density_per_km²',
#  'Growth_Rate',
#  'World_Population_Percentage']

# %%
# Check again for missing values
print("\n Final check for missing values:")
df.isnull().sum()
# Out:
#  Final check for missing values:
# Rank                           0
# Country/Territory              0
# Continent                      0
# 2022_Population                0
# 2020_Population                0
# 2015_Population                0
# 2010_Population                0
# 2000_Population                0
# 1990_Population                0
# 1980_Population                0
# 1970_Population                0
# Area_km²                       0
# Density_per_km²                0
# Growth_Rate                    0
# World_Population_Percentage    0
# dtype: int64

# %% [markdown]
# <center><h3 style="background-color: #FFD54F;color:#222222"><i> PART 3: Exploratory Data Analysis (EDA)</i></h3>

# %%
# 1. Top 10 most populated countries in 2022
top10=df.sort_values(by='2022_Population',ascending=False).head(10)
plt.figure(figsize=(10 , 6))
sns.barplot(x='2022_Population' , y='Country/Territory', data=top10, palette='viridis')
plt.title('Top 10 Most Populated Countries (2022)')
plt.xlabel('Population (2022)')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %%
# 2. Population by Continent (2022)
continent_pop = df.groupby('Continent')['2022_Population'].sum().sort_values(ascending=False)

plt.Figure(figsize=(8, 5))
continent_pop.plot(kind='bar' , color='teal')
plt.title(' Population by Continent (2022)')
plt.ylabel('Total Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 3. Distribution of Growth Rates
plt.Figure(figsize=(8, 5))
sns.histplot(df['Growth_Rate'], bins=20 ,kde=True ,color='orange')
plt.title(' Growth Rate Distribution')
plt.xlabel('Growth Rate (%)')
plt.tight_layout()
plt.show()

# %%
# 4. Top 10 Densely Populated Countries
top10_density=df.sort_values(by='Density_per_km²' , ascending=False).head(10)
plt.Figure(figsize=(10, 6))
sns.barplot(x='Density_per_km²', y='Country/Territory', data=top10_density, palette='magma')
plt.title('Top 10 Densely Populated Countries')
plt.xlabel('Population Density (per km²)')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# <center><h3 style="background-color: #FFD54F;color:#222222"><bold><i>  Part 4 – Feature Engineering</i></h3>

# %% [markdown]
# #### Step 1: Create a New Column – Population Growth

# %%
# Creating a new column to calculate total population growth from 1970 to 2022
# Subtract 1970 population from 2022 population
df['Population_Growth_(1970_to_2022)'] = df['2022_Population'] - df['1970_Population']

# %% [markdown]
# #### Step 2: Calculate Average Growth Per Year (Over 52 Years)

# %%
# Calculating average yearly population growth
# Total growth / 52 years (from 1970 to 2022)
df['Avg_Growth_Per_Year'] = df['Population_Growth_(1970_to_2022)'] / 52

# %% [markdown]
# #### Step 3: Calculate Growth Rate from 2000 to 2022

# %%
# Calculating population growth rate (in %) from 2000 to 2022
# Formula: ((2022 - 2000 population) / 2000 population) * 100
df['Pop_Growth_Rate_2000_to_2022']=((df['2022_Population'] - df['2000_Population']) / df['2000_Population'] * 100)

# %% [markdown]
# #### Step 4: Check the Updated DataFrame

# %%
# Let's check a few rows to see if new columns were added correctly
df[['Country/Territory', 
    '2022_Population', 
    '1970_Population', 
    '2000_Population', 
    'Population_Growth_(1970_to_2022)', 
    'Avg_Growth_Per_Year', 
    'Pop_Growth_Rate_2000_to_2022']].head(10)
# Out:
#      Country/Territory  2022_Population  1970_Population  2000_Population  \
# 0          Afghanistan         41128771         10752971         19542982
# 1              Albania          2842321          2324731          3182021
# 2              Algeria         44903225         13795915         30774621
# 3       American Samoa            44273            27075            58230
# 4              Andorra            79824            19860            66097
# 5               Angola         35588987          6029700         16394062
# 6             Anguilla            15857             6283            11047
# 7  Antigua and Barbuda            93763            64516            75055
# 8            Argentina         45510318         23842803         37070774
# 9              Armenia          2780469          2534377          3168523
#
#    Population_Growth_(1970_to_2022)  Avg_Growth_Per_Year  \
# 0                          30375800        584150.000000
# ...

# %% [markdown]
# <center><h3 style="background-color: #FFD54F;color:#222222"><bold><i>   Part 5 – Correlation Analysis </i></h3>

# %%
#Step 1: Calculate Correlation Matrix
# This matrix shows the relationship (correlation) between all numeric features.
# Value close to 1 means strong positive relationship; close to -1 means negative relationship.
correlation_matrix=df.corr(numeric_only=True)

# %%
#Step 2: Visualize the Correlation Matrix with Heatmap
plt.Figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# # THANK YOU .....
